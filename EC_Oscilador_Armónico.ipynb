# %% [markdown]
# <a href="https://colab.research.google.com/github/florgaleana/Notas-de-clase/blob/main/EC_Oscilador_Arm%C3%B3nico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ecuación Diferencial para oscilador armónico.
#Autor: Flor Marián Galeana Juárez
#Fecha: 28 de septiembre del 2021

import matplotlib.pyplot as plt
import numpy as np
def f(k,m,t):
  return np.sin(np.sqrt(k/m)*t)
t1= np.arange (0,2, 0.001)
k= float ( input("¿Cuál es la constante del resorte? ")) #N/m
t= float ( input("¿En qué tiempo quieres calcular la función? ")) #Segundos
m= float ( input ("¿Cuál es la masa en kilos? ")) #Kg
print("el resultado es", f(k,m,t))
plt.plot(t1, f(k,m,t1))
plt.show()
# Out:
# ¿Cuál es la constante del resorte? 200
# ¿En qué tiempo quieres calcular la función? 2
# ¿Cuál es la masa en kilos? 0.1
# el resultado es 0.9957090662139695

# %%
#Derivada de la función original
import matplotlib.pyplot as plt
import numpy as np
import sympy
from scipy.misc import derivative
#Definimos funciones:
def f(k,m,t): #derivada numérica
  return np.sin(np.sqrt(k/m)*t)
#def f1(k,m,t):
  #return (np.sin((t+intervalo)*np.sqrt(k/m))-(np.sin(np.sqrt(k/m)*t)))/intervalo
#Lectura de variables
t1= np.arange (0,2, 0.001)
k= float ( input("¿Cuál es la constante del resorte? ")) #N/m
t= float ( input("¿En qué punto tiempo quieres calcular la derivada de la función? ")) #Segundos
m= float ( input ("¿Cuál es la masa en kilos? ")) #Kg
intervalo= float (input("¿En qué intervalo quieres calcular la derivada? "))
#Calculamos la derivada:
Derivada1= (f(k,m,t+intervalo)- f(k,m,t))/intervalo
primera_derivada= f(k,m,t1)
#Imprimimos funciones:
print("La primera derivada numérica de la función es: ", Derivada1)
#Graficamos:
plt.plot(t1, f1(k,m,t1), label= "f1(k,m,t)")
plt.plot(t1, primera_derivada, label= "Primera derivada")
plt.xlabel("Variable independiente (t) [units]")
plt.ylabel("f(t) [units]")
plt.legend()
plt.show()
# Out:
# ¿Cuál es la constante del resorte? 200
# ¿En qué punto tiempo quieres calcular la derivada de la función? 2
# ¿Cuál es la masa en kilos? 0.1
# ¿En qué intervalo quieres calcular la derivada? 0.0000001
# La primera derivada numérica de la función es:  4.138367635242446

# %%
#Segunda derivada
import matplotlib.pyplot as plt
import numpy as np
import sympy
from scipy.misc import derivative
#Definimos funciones:
def f(k,m,t): #derivada numérica
  return np.sin(np.sqrt(k/m)*t)
#Lectura de variables
t1= np.arange (0,2, 0.001)
k= float ( input("¿Cuál es la constante del resorte? ")) #N/m
t= float ( input("¿En qué punto tiempo quieres calcular la derivada de la función? ")) #Segundos
m= float ( input ("¿Cuál es la masa en kilos? ")) #Kg
intervalo= float (input("¿En qué intervalo quieres calcular la derivada? "))
#Calculamos la segunda derivada:
Derivada2= (((np.sin((t+2*intervalo)*np.sqrt(k/m))-np.sin((t+intervalo)*np.sqrt(k/m)))/intervalo)-((np.sin((t+intervalo)*np.sqrt(k/m))-np.sin(t*np.sqrt(k/m)))/intervalo))/intervalo
def f2(k,m,t):
  return (((np.sin((t+2*intervalo)*np.sqrt(k/m))-np.sin((t+intervalo)*np.sqrt(k/m)))/intervalo)-((np.sin((t+intervalo)*np.sqrt(k/m))-np.sin(t*np.sqrt(k/m)))/intervalo))/intervalo
segunda_derivada= f2(k,m,t1)
#Imprimimos funciones:
print("La segunda derivada numérica de la función es: ", Derivada2)
#Graficamos:
plt.plot(t1, f1(k,m,t1), label= "f1(k,m,t)")
plt.plot(t1, segunda_derivada, label= "segunda derivada")
plt.xlabel("Variable independiente (t) [units]")
plt.ylabel("f(t) [units]")
plt.legend()
plt.show()
# Out:
# ¿Cuál es la constante del resorte? 200
# ¿En qué punto tiempo quieres calcular la derivada de la función? 2
# ¿Cuál es la masa en kilos? 0.1
# ¿En qué intervalo quieres calcular la derivada? 0.000001
# La segunda derivada numérica de la función es:  -1991.4291327083333
