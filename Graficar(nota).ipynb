# %% [markdown]
# <a href="https://colab.research.google.com/github/florgaleana/Prueba/blob/main/Graficar(nota).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
#Bibliotecas:
#https://numpy.org/doc/stable/reference/generated/numpy.arange.html
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html
def f1(x):
  return -1.00*(x**2)+3*x #(-x2)+3x

t1= np.arange(-10, 15, 0.1)

plt.plot(t1, f1(t1))
plt.grid(color= "r", linestyle="-", linewidth=2)
plt.show()
