# %% [markdown]
# <a href="https://colab.research.google.com/github/florgaleana/Notas-de-clase/blob/main/Gr%C3%A1ficas_de_movimiento_oscilador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Oscilador armónico
#Flor Marián Galeana Juárez
#01 de septiembre del 2021
import matplotlib.pyplot as plt
import numpy as np
import math
def f1 (A,w,t):
  return A*np.sin(w*t)
t1= np.arange (0, 10, 0.1)
def fx (A, w, t, h):
  return (A*(math.sin(w*(t+h))) - A*(math.sin(w*(t))))/h
t1= np.arange (0, 10, 0.1)
A= float (input("inserte un valor para la amplitud "))
T= float (input ("inserte un valor para el periodo "))
t= 3 #tiempo
h= 0.5
w= (2*math.pi)/T #frecuencia angular
#f1= A*np.sin(w*t)
fx = (A*(math.sin(w*(t+h))) - A*(math.sin(w*(t))))/h
print("la velocidad del oscilador es", fx, "en el intervalo de", h, "segundos")
plt.plot(t1, f1(A,w,t1))
plt.plot(t1, f1(A,w,t1+h))
plt.show()
# Out:
# inserte un valor para la amplitud 5
# inserte un valor para el periodo 2
# la velocidad del oscilador es -10.000000000000004 en el intervalo de 0.5 segundos
